# %%
import os
import boto3
from dotenv import load_dotenv

#Chargement des identifiants depuis le fichier d'environnement (bloqué sur github par .gitignore de *.env)
load_dotenv("credential.env")
s3_client = boto3.client(
    's3',
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    region_name="eu-west-3"
)

# connexion au bucket 'certification-kayak'
fichier_local = r"src\kayak_ds.csv"        
nom_bucket = os.getenv("AWS_BUCKET_NAME")  
cle_s3 = "kayak_ds.csv"

#envoi du fichier
try:
    s3_client.upload_file(Filename=fichier_local, Bucket=nom_bucket, Key=cle_s3)
    print("dépôt réussi")
except Exception as e:
    print(f"Erreur lors de l'envoi : {e}")
# Out:
# Connexion au service de stockage Amazon S3...
# Téléversement de src\kayak_ds.csv vers le bucket certification-kayak...
# --- ARCHIVAGE S3 RÉUSSI : Le fichier est disponible dans le Data Lake ---
